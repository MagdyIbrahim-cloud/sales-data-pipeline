# %%
load_type = dbutils.widgets.get("load_type")

notebooks = [
    ("./silver_customers", {}),
    ("./silver_products", {}),
    ("./silver_gross_price", {}),
    ("./silver_load", {"load_type": load_type})
]

for nb, args in notebooks:
    print(f"Running --> {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0, arguments=args)
