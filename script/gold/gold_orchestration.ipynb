# %%
notebooks = [
    "./sb_dim_customers",
    "./sb_dim_products",
    "./sb_dim_gross_price",
    "./gold_incremental_load"
]

for nb in notebooks:
    print(f"Running --> {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
