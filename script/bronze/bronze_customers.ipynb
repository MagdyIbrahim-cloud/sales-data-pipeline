# %% [markdown]
# #Initialization

# %%
from pyspark.sql import functions as f

# %% [markdown]
# #Read table from S3 bucket

# %%
file_path = "s3://sportpro-db/customers/*.csv"

# %%
df = (
    spark.read.format("csv")
        .option("header", True)
        .option("inferschema", True)
        .load(file_path)
        .withColumn("read_timestamp", f.current_timestamp())
        .select("*", "_metadata.file_name", "_metadata.file_size")
)

# %% [markdown]
# ##Check dataframe

# %%
display(df.limit(10))

# %% [markdown]
# #Write table to bronze

# %%
df.write \
    .mode("overwrite") \
    .format("delta") \
    .option("dalta.enableChangeDataFeed", "true") \
    .saveAsTable("pcat.bronze.customers")
